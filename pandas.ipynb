# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Series

# %%
series = pd.Series(["BMW", "Honda", "Toyota"])

# %%
series
# Out:
# 0       BMW
# 1     Honda
# 2    Toyota
# dtype: object

# %%
colors = pd.Series(["Green", "Blue", "Black"])

# %%
colors
# Out:
# 0    Green
# 1     Blue
# 2    Black
# dtype: object

# %% [markdown]
# # DataFrame

# %%
df = pd.DataFrame({"colors":colors, "cars":series})

# %%
df
# Out:
#   colors    cars
# 0  Green     BMW
# 1   Blue   Honda
# 2  Black  Toyota

# %% [markdown]
# # CSV

# %%
csv_df = pd.read_csv("carData.csv")

# %%
csv_df
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
csv_df.select_dtypes(np.number).mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %% [markdown]
# # Data

# %%
csv_df[csv_df["Odometer (KM)"] > 100000][["Make", "Price"]]
# Out:
#      Make       Price
# 0  Toyota  $4,000.00
# 4  Nissan  $3,500.00

# %%
csv_df.groupby(['Make']).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# # Lecture - 58

# %%
car_shuffeled = csv_df.sample(frac=1)
#frac is how much

# %%
# only 20% for smaller data
car_shuffeled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 3     BMW  Black          11179      5  $22,000.00
# 8  Toyota  White          60000      4   $6,250.00

# %%
car_shuffeled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors        Price
# 0      2  Toyota   Blue          32549      3   $7,000.00
# 1      5  Toyota  Green          99213      4   $4,500.00
# 2      8  Toyota  White          60000      4   $6,250.00
# 3      3     BMW  Black          11179      5  $22,000.00
# 4      4  Nissan  White         213095      4   $3,500.00
# 5      6   Honda   Blue          45698      4   $7,500.00
# 6      1   Honda    Red          87899      4   $5,000.00
# 7      7   Honda   Blue          54738      4   $7,000.00
# 8      0  Toyota  White         150043      4   $4,000.00
# 9      9  Nissan  White          31600      4   $9,700.00

# %%
car_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 2  Toyota   Blue          32549      3   $7,000.00
# 5  Toyota  Green          99213      4   $4,500.00
# 8  Toyota  White          60000      4   $6,250.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 1   Honda    Red          87899      4   $5,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 0  Toyota  White         150043      4   $4,000.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_shuffeled.reset_index(drop = True, inplace=True)

# %%
car_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota   Blue          32549      3   $7,000.00
# 1  Toyota  Green          99213      4   $4,500.00
# 2  Toyota  White          60000      4   $6,250.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5   Honda   Blue          45698      4   $7,500.00
# 6   Honda    Red          87899      4   $5,000.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White         150043      4   $4,000.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_shuffeled["Odometer (KM)"] = car_shuffeled["Odometer (KM)"].apply(lambda x : x/1.6)

# %%
car_shuffeled
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota   Blue      20343.125      3   $7,000.00
# 1  Toyota  Green      62008.125      4   $4,500.00
# 2  Toyota  White      37500.000      4   $6,250.00
# 3     BMW  Black       6986.875      5  $22,000.00
# 4  Nissan  White     133184.375      4   $3,500.00
# 5   Honda   Blue      28561.250      4   $7,500.00
# 6   Honda    Red      54936.875      4   $5,000.00
# 7   Honda   Blue      34211.250      4   $7,000.00
# 8  Toyota  White      93776.875      4   $4,000.00
# 9  Nissan  White      19750.000      4   $9,700.00
