# %% [markdown]
# # introduction of matplot.lib

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4]);

# %%
plt.plot([1,2,3,4], [12,23,15,63]);

# %%
# 1st method
fig = plt.figure() # creates a figure
fig.add_subplot() # adds some axes
plt.show()

# %%
x = [1,2,3,4]
y = [11,22,33,44]

# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([5,10,1,1]) # adds some axes
ax.plot(x, y)
plt.show()

# %%
# 3rd method
fig, ax = plt.subplots() # creates a figure and asxes
ax.plot(x, y);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# ## matplotlib example code workflow

# %%
# 0) import matplot lib

# %matplotlib inline
import matplotlib.pyplot as plt

# 1) prepare the data

x = [1,2,5,6]
y=[43,52,23,64]

# 2) setup data
fig,ax = plt.subplots(figsize=(10,10)) #(width, height)

# 3) plot data
ax.plot(x,y)

# 4) customize plot
ax.set(title="simple plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5) save fig
fig.savefig("./images/SP.png")

# %% [markdown]
# ## making figures with numpy arrays
# we want:
# * line plot
# * bar plot
# * scatter plot
# * histogram
# * subplot

# %%
import numpy as np

# %%
# create sonme data
x = np.linspace(0,10,100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
fig, ax = plt.subplots()
ax.plot(x,x**2);

# %%
# use th same data to make scatter plot
fig,ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
fig,ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# make a plot with dictionary 
nut_butter_prices = {"Almond Butter":10,
                    "Peanut Butter":8,
                    "Cashew Butter":12}
fig,ax=plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title="Nut Butter Prices In Stores", xlabel="Type", ylabel="Price($)")
# Out:
# [Text(0.5, 1.0, 'Nut Butter Prices In Stores'),
#  Text(0.5, 0, 'Type'),
#  Text(0, 0.5, 'Price($)')]

# %%
fig,ax = plt.subplots()

ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
x = np.random.randn(1000)
fig,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ### making subplots

# %%
# option 1
fig,((ax1, ax2, ax5), (ax3, ax4, ax6)) = plt.subplots(nrows=2,
                                          ncols=3,
                                          figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(),np.random.random(3))
ax4.hist(np.random.randn(1000));

# %%
# plot subplot option 2
fig,ax = plt.subplots(nrows=2,
                     ncols=2,
                     figsize=(10,5))
ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].barh(list(nut_butter_prices.keys()), list(np.random.random(3)))
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## ploting from data frame

# %%
import pandas as pd

# %%
# making a dataframe
carCsv = pd.read_csv("./data/carData.csv")
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index=pd.date_range("1/1/2024", periods=1000))

# %%
ts
# Out:
# 2024-01-01    1.389663
# 2024-01-02    1.057721
# 2024-01-03    0.718833
# 2024-01-04   -0.939272
# 2024-01-05   -0.015100
#                 ...
# 2026-09-22   -2.093463
# 2026-09-23   -0.046859
# 2026-09-24   -1.448622
# 2026-09-25   -0.363517
# 2026-09-26   -0.971671
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <Axes: >

# %%
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carCsv["Price"] = carCsv["Price"].str.replace('[\$\,\.]', '', regex=True)
carCsv
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\Vaibhav Saini\AppData\Local\Temp\ipykernel_17244\45731350.py:1: SyntaxWarning: invalid escape sequence '\$'
#   carCsv["Price"] = carCsv["Price"].str.replace('[\$\,\.]', '', regex=True)
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# remove last 2 digits
carCsv["Price"] = carCsv["Price"].str[:-1]

# %%
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
carCsv["Sale date"] = pd.date_range("1/1/2024", periods=len(carCsv))

# %%
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale date
# 0  Toyota  White         150043      4   400000 2024-01-01
# 1   Honda    Red          87899      4   500000 2024-01-02
# 2  Toyota   Blue          32549      3   700000 2024-01-03
# 3     BMW  Black          11179      5  2200000 2024-01-04
# 4  Nissan  White         213095      4   350000 2024-01-05
# 5  Toyota  Green          99213      4   450000 2024-01-06
# 6   Honda   Blue          45698      4   750000 2024-01-07
# 7   Honda   Blue          54738      4   700000 2024-01-08
# 8  Toyota  White          60000      4   625000 2024-01-09
# 9  Nissan  White          31600      4   970000 2024-01-10

# %%
carCsv["Total"] = carCsv["Price"].astype(int).cumsum()

# %%
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale date    Total
# 0  Toyota  White         150043      4   400000 2024-01-01   400000
# 1   Honda    Red          87899      4   500000 2024-01-02   900000
# 2  Toyota   Blue          32549      3   700000 2024-01-03  1600000
# 3     BMW  Black          11179      5  2200000 2024-01-04  3800000
# 4  Nissan  White         213095      4   350000 2024-01-05  4150000
# 5  Toyota  Green          99213      4   450000 2024-01-06  4600000
# 6   Honda   Blue          45698      4   750000 2024-01-07  5350000
# 7   Honda   Blue          54738      4   700000 2024-01-08  6050000
# 8  Toyota  White          60000      4   625000 2024-01-09  6675000
# 9  Nissan  White          31600      4   970000 2024-01-10  7645000

# %%
 # let's plot the total sales
carCsv.plot(x="Sale date", y = "Total")
# Out:
# <Axes: xlabel='Sale date'>

# %%
carCsv["Price"] = carCsv["Price"].astype(int)
carCsv.plot(x="Odometer (KM)", y="Price", kind="scatter")
# Out:
# <Axes: xlabel='Odometer (KM)', ylabel='Price'>

# %%
x = np.random.rand(10,4)
df = pd.DataFrame(x, columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.760163  0.118012  0.835855  0.700026
# 1  0.257099  0.335061  0.695445  0.947347
# 2  0.299259  0.316988  0.902361  0.422206
# 3  0.823061  0.358582  0.299413  0.341525
# 4  0.487565  0.045467  0.345792  0.755021
# 5  0.609451  0.771253  0.574272  0.585651
# 6  0.712360  0.158796  0.224662  0.956312
# 7  0.217396  0.825337  0.992214  0.646257
# 8  0.731833  0.401713  0.568066  0.381471
# 9  0.152206  0.213824  0.101041  0.199640

# %%
df.plot.bar();

# %%
df.plot();

# %%
df.plot(kind="bar")
# Out:
# <Axes: >

# %%
carCsv
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale date    Total
# 0  Toyota  White         150043      4   400000 2024-01-01   400000
# 1   Honda    Red          87899      4   500000 2024-01-02   900000
# 2  Toyota   Blue          32549      3   700000 2024-01-03  1600000
# 3     BMW  Black          11179      5  2200000 2024-01-04  3800000
# 4  Nissan  White         213095      4   350000 2024-01-05  4150000
# 5  Toyota  Green          99213      4   450000 2024-01-06  4600000
# 6   Honda   Blue          45698      4   750000 2024-01-07  5350000
# 7   Honda   Blue          54738      4   700000 2024-01-08  6050000
# 8  Toyota  White          60000      4   625000 2024-01-09  6675000
# 9  Nissan  White          31600      4   970000 2024-01-10  7645000

# %%
carCsv.groupby("Make").plot(x="Make", y="Odometer (KM)", kind="bar")
# Out:
# Make
# BMW       Axes(0.125,0.11;0.775x0.77)
# Honda     Axes(0.125,0.11;0.775x0.77)
# Nissan    Axes(0.125,0.11;0.775x0.77)
# Toyota    Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
carCsv["Odometer (KM)"].plot.hist();

# %% [markdown]
# ### which method would u use(pyplot vs matplotlib oo)
# * when ploting something quicly ok to use pyplot
# * when ploting something advance use the OO method

# %%
heartCsv = pd.read_csv("./data/heart-disease.csv")
heartCsv
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over50 = heartCsv[heartCsv["age"]>50]
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(over50)
# Out:
# 208

# %%
# pyplot method
over50.plot(kind="scatter",
           x="age",
           y="chol",
           c="target")
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
# OO method
fix, ax = plt.subplots(figsize=(10,6))
over50.plot(kind="scatter",x="age",y="chol",c="target",ax=ax);
# ax.set_xlim([45,100])

# %%
## OO method
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over50["age"], y=over50["chol"], c=over50["target"]);
ax.set_xlim([45,80])
ax.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(), title="target")
ax.axhline(over50["chol"].mean(), linestyle="--")

# %% [markdown]
# # suplot of chol, age, thalach

# %%
plt.style.use("classic")
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))
scatterChol = ax0.scatter(x=over50["age"], y=over50["chol"], c=over50["target"]);
ax0.set_xlim([45,80])
ax0.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Cholestrol")
ax0.legend(*scatterChol.legend_elements(), title="target")
ax0.axhline(over50["chol"].mean(), linestyle="--")

scatterThalach = ax1.scatter(x=over50["age"], y=over50["thalach"], c=over50["target"]);
ax1.set_xlim([45,80])
ax1.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Max hearteat")
ax1.legend(*scatterThalach.legend_elements(), title="target")
ax1.axhline(over50["thalach"].mean(), linestyle="--")
fig.suptitle("Heart Disease Analysis", fontsize="16", fontweight="bold");

# %% [markdown]
# ## customizing the matplotlib plot and getting stylish

# %%
# see the different styles availabe
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
carCsv["Price"].plot();

# %%
plt.style.use("seaborn-v0_8-whitegrid");

# %%
carCsv["Price"].plot()
# Out:
# <Axes: >

# %%
plt.style.use("dark_background")

# %%
carCsv["Price"].plot()
# Out:
# <Axes: >

# %%
x=np.random.randn(10,4)
df=pd.DataFrame(x,columns=['a','b','c','d'])
ax=df.plot(kind="bar")
ax.set(title="random number bar graph from dataframe",
       xlabel="row number",
       ylabel="random number")
ax.legend().set_visible(True)

# %%
plt.style.use("seaborn-v0_8-whitegrid")
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over50["age"], 
                     y=over50["chol"], 
                     c=over50["target"], 
                     cmap="winter", # this changes the color scheme 
                     #s=[80]
                    );
ax.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Cholestrol")
ax.legend(*scatter.legend_elements(), title="target")
ax.axhline(over50["chol"].mean(), linestyle="--");

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))
scatterChol = ax0.scatter(x=over50["age"], y=over50["chol"], c=over50["target"], cmap="winter", s=[70]);
ax0.set_xlim([50,80])
# ax0.set_ylim([45,80])
ax0.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Cholestrol")
ax0.legend(*scatterChol.legend_elements(), title="target")
ax0.axhline(over50["chol"].mean(), linestyle="--", c=(1,0,0), linewidth = 2)

scatterThalach = ax1.scatter(x=over50["age"], y=over50["thalach"], c=over50["target"], cmap="winter", s=[70]);
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
ax1.set(title="Heart Diesease and Cholestrol levers", xlabel="Age", ylabel="Max hearteat")
ax1.legend(*scatterThalach.legend_elements(), title="target")
ax1.axhline(over50["thalach"].mean(), linestyle="--", c=(1,0,0), linewidth = 2)
fig.suptitle("Heart Disease Analysis", fontsize="16", fontweight="bold");

# %%
heartCsv
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...
